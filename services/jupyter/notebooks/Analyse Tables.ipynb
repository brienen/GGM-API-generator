# %%
import config
import pymongo
import numpy as np
import pandas as pd
import json
import re
import ast

import sqlalchemy as db
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine, inspect
from sqlalchemy.engine import reflection

# %%
myclient = pymongo.MongoClient(str(config.MONGO_URI))
stagingDb = myclient[str(config.DB_STAGING)]
analyseDb = myclient[str(config.DB_ANALYSE)]
stagingCol = stagingDb[config.COLL_PLAATJES]
stagingOud = stagingDb[config.COLL_STAGING_OUD]
stagingNieuw = stagingDb[config.COLL_STAGING_NIEUW]
analyseCol = analyseDb[config.COLL_ANALYSE]
analyseColClean = analyseDb[config.COLL_ANALYSE_CLEAN]

metaCollection = stagingDb['Kolominformatie']
AIRFLOW_WASSTRAAT_CONFIG = "./wasstraat_config/Wasstraat_Config_Harmonize.xlsx"

# %%
def AggregateData(df, fase): 
    df['teller'] = pd.to_numeric(df['teller'])
    df = df.groupby('table').agg({'project':lambda x: list(x), 'teller':lambda x: sum(x)})
    df['Count'] = df.apply(lambda x: len(x.project), axis=1)
    df['Stage'] = fase
    df = df.sort_values('teller', ascending=False).reset_index()
    df = df.rename(columns={'table': 'Table', 'project': 'Projecten', 'teller': 'Aantal_Records', 'Count': 'Aantal_tabellen'}).sort_index()
    return df

# %%
xl = pd.read_excel(AIRFLOW_WASSTRAAT_CONFIG, None);
df_table = xl['Objecten']
ignore_kolommen = df_table[df_table['Object'] == 'Ignore']['Tabellen'].values[0]
ignore_lst = ast.literal_eval(ignore_kolommen)

ignore_lst
# Out:
# ['.*backup.*', '.*kopie.*']

# %%
grp_aggr = [{"$match" : {'project': {'$nin': ['MAGAZIJN', 'DELF-IT', 'Digifotos']}, 'table': { '$not': {'$regex':"^SYS.*"}}}},
            {"$group": { "_id": { 'project': "$project", 'table': "$table", 'teller': '$teller'}}},
            {'$replaceRoot': {'newRoot': {'project': "$_id.project", 'table': "$_id.table", 'teller': "$_id.teller"}}}]

df_brondata = AggregateData(pd.DataFrame(list(metaCollection.aggregate(grp_aggr))), 'Brondata')
df_brondata.head(5)
# Out:
#                 Table                                          Projecten  \
# 0         AARDEWERK 1                                 [DC97, DB34, HHD2]
# 1  Aardewerk 1 backup                                             [DB34]
# 2       VONDSTENLIJST  [DC32, DC22, DC11, DC33, DC18, DC93, DC20, DC1...
# 3        DIAOPGRAVING  [HHD2, DC97, DC93, DC27, DC20, DC22, DC30, DC2...
# 4   Controle vondsten                                             [DB34]
#
#    Aantal_Records  Aantal_tabellen     Stage
# 0            5440                3  Brondata
# 1            4465                1  Brondata
# 2            3992               15  Brondata
# 3            2057               13  Brondata
# 4            1466                1  Brondata

# %%
grp_aggr = [{"$match" : {'project': {'$nin': ['MAGAZIJN', 'DELF-IT', 'Digifotos']}, 'table': { '$not': {'$regex':"^SYS.*"}}}}
           ,{"$group": { "_id": { 'project': "$project", 'table': "$table"}, 'teller': {"$sum": 1}}}
           ,{'$replaceRoot': {'newRoot': {'project': "$_id.project", 'table': "$_id.table", 'teller': "$teller"}}}]

df_staging = AggregateData(pd.concat([pd.DataFrame(list(stagingOud.aggregate(grp_aggr))), pd.DataFrame(list(stagingNieuw.aggregate(grp_aggr)))]), 'Staging')
df_staging.head(5)
df_staging[df_staging.Table.str.contains('VONDST')]
# Out:
#                                    Table  \
# 2                          VONDSTENLIJST
# 25                            VONDSTINHD
# 34                                VONDST
# 35                            VAK_VONDST
# 45  LIJST VONDSTEN  URGENTE CONSERVERING
#
#                                             Projecten  Aantal_Records  \
# 2   [DB34, DC30, HHD2, DC34, DC33, DC18, DC32, DC9...            3992
# 25                  [DC24_STADSKANTOOR, DC154, DC179]             300
# 34                  [DC154, DC24_STADSKANTOOR, DC179]             205
# 35                                            [DC179]             204
# 45                                             [DB34]             129
#
#     Aantal_tabellen    Stage
# 2                15  Staging
# 25                3  Staging
# 34                3  Staging
# 35                1  Staging
# 45                1  Staging

# %%
grp_aggr = [{'$group': {'_id': {'project': "$brondata.project", 'table': "$brondata.table"},'teller': {"$sum": 1}}}
           ,{'$replaceRoot': {'newRoot': {'project': "$_id.project", 'table': "$_id.table", 'teller': "$teller"}}}]

df_singlestore = AggregateData(pd.DataFrame(list(analyseCol.aggregate(grp_aggr))), 'SingleStore')
df_singlestore.head(5)
# Out:
#            Table                                          Projecten  \
# 0  magazijnlijst                                         [MAGAZIJN]
# 1         doosnr                                         [MAGAZIJN]
# 2    AARDEWERK 1                                 [DC97, DB34, HHD2]
# 3  VONDSTENLIJST  [DC93, DC30, DB34, DC32, DC18, DC33, DC97, DC3...
# 4         SPOREN        [DB34, DC112, HHD2, DC97, DC93, DC29, DC30]
#
#    Aantal_Records  Aantal_tabellen        Stage
# 0           11268                1  SingleStore
# 1            5546                1  SingleStore
# 2            5440                3  SingleStore
# 3            3992               15  SingleStore
# 4            1174                7  SingleStore

# %%
grp_aggr = [{'$group': {'_id': {'project': "$brondata.project", 'table': "$brondata.table"},'teller': {"$sum": 1}}}
           ,{'$replaceRoot': {'newRoot': {'project': "$_id.project", 'table': "$_id.table", 'teller': "$teller"}}}]

df_singlestoreclean = AggregateData(pd.DataFrame(list(analyseColClean.aggregate(grp_aggr))), 'SingleStoreClean')
df_singlestoreclean.head(5)
# Out:
#               Table                                          Projecten  \
# 0     magazijnlijst                                         [MAGAZIJN]
# 1            doosnr                                         [MAGAZIJN]
# 2       AARDEWERK 1                                 [DC97, DB34, HHD2]
# 3     VONDSTENLIJST  [DC97, DC39, DC11, DC112, DC22, DC29, DC20, DC...
# 4  generated_vondst  [DC013, DC027, DC037, DC021, DC030, DC022, DC0...
#
#    Aantal_Records  Aantal_tabellen             Stage
# 0           11268                1  SingleStoreClean
# 1            5546                1  SingleStoreClean
# 2            5440                3  SingleStoreClean
# 3            3992               15  SingleStoreClean
# 4            2112               27  SingleStoreClean

# %%
lst_tables = ['Def_Project', 'Def_Vondst', 'Def_Stelling', 'Def_Plaatsing', 'Def_Vindplaats', 'Def_Artefact', 'Def_Spoor', 'Def_Doos']
regexTable = re.compile(r'\'table\': \'(.*?)\'') # regex to replace Object
regexProject = re.compile(r'\'project\': \'(.*?)\'') # regex to replace Object

def getTable(brondata):    
    #print(brondata)
    if brondata is None or brondata != "":
        return regexTable.search(brondata).group(1)
    else: 
        return "" 
def getProject(brondata):    
    #print(brondata)
    if brondata is None or brondata != "":
        return regexProject.search(brondata).group(1)
    else: 
        return "" 

df_tables_projects = pd.DataFrame()
    
engine = create_engine(config.SQLALCHEMY_DATABASE_URI)
with engine.connect() as connection:
    for table in lst_tables:     
        df = pd.read_sql_query('SELECT brondata from "' + table + '"', connection)
        
        df_out = pd.DataFrame()
        df_out['table'] = df.apply(lambda x: getTable(x['brondata']), axis=1)
        df_out['project'] = df.apply(lambda x: getProject(x['brondata']), axis=1)
        df_tables_projects = pd.concat([df_tables_projects, pd.DataFrame(df_out).groupby(['project', 'table']).size().reset_index(name='teller')])
    
df_doelsysteem = AggregateData(df_tables_projects, 'Doelsysteem')
df_doelsysteem.head(5)
# Out:
#               Table                                          Projecten  \
# 0     magazijnlijst                                         [MAGAZIJN]
# 1       AARDEWERK 1                                 [DB34, DC97, HHD2]
# 2     VONDSTENLIJST  [DB34, DC11, DC112, DC18, DC20, DC22, DC29, DC...
# 3            doosnr                                         [MAGAZIJN]
# 4  generated_vondst  [DB008, DB034, DC004, DC005, DC008, DC009, DC0...
#
#    Aantal_Records  Aantal_tabellen        Stage
# 0            5634                1  Doelsysteem
# 1            5440                3  Doelsysteem
# 2            3992               15  Doelsysteem
# 3            2773                1  Doelsysteem
# 4            2112               27  Doelsysteem

# %% [markdown]
# ## Analyse van alle gegevens
#
# Hieronder volgt een overzicht van alle gegevens die in de vier fases beschikbaar zijn. Zo kunnen fouten in de conversie worden opgespoord.

# %%
def getOverview(OnWhat): 
    lst_countColumns = [OnWhat + '_brondata', OnWhat + '_staging', OnWhat + '_singlestore', OnWhat + '_singlestoreclean', OnWhat + '_doelsysteem']
    
    df = df_brondata[['Table', 'Projecten', OnWhat]].merge(df_staging[['Table', OnWhat]], on=['Table'], how='outer', suffixes=("_brondata", "_staging"))
    df = df.merge(df_singlestore[['Table', OnWhat]], on=['Table'], how='outer', suffixes=("_staging", "_singlestore"))
    df = df.merge(df_singlestoreclean[['Table', OnWhat]], on=['Table'], how='outer', suffixes=("_singlestore", "_singlestoreclean"))
    df = df.merge(df_doelsysteem[['Table', OnWhat]], on=['Table'], how='outer', suffixes=("_singlestoreclean", "_doelsysteem"))

    df = df.sort_values(OnWhat+ '_brondata', ascending=False) 
    df.rename(columns={'Aantal_Records': 'Aantal_Records_doelsysteem'}, inplace=True)
    df[lst_countColumns] = df[lst_countColumns].fillna(0)
    df[lst_countColumns] = df[lst_countColumns].astype(int, errors='ignore')
    #df = df[df.Table.str.contains('vondst', case=False)]
    df = df.style.bar(subset=lst_countColumns, color='#5fba7d', vmax=6000)
    
    return df

getOverview('Aantal_Records')
# Out:
# <style  type="text/css" >
# #T_24cdff9a_9964_11ec_902e_0242c0a83004row0_col2,#T_24cdff9a_9964_11ec_902e_0242c0a83004row0_col3,#T_24cdff9a_9964_11ec_902e_0242c0a83004row0_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row0_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.7%, transparent 90.7%);
#         }#T_24cdff9a_9964_11ec_902e_0242c0a83004row1_col2,#T_24cdff9a_9964_11ec_902e_0242c0a83004row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.4%, transparent 74.4%);
#         }#T_24cdff9a_9964_11ec_902e_0242c0a83004row1_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row1_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row1_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row3_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row3_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row3_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row4_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row4_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row4_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row6_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row6_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row6_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row14_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row14_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row14_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row15_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row15_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row15_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row16_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row16_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row16_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row21_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row21_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row21_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row24_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row24_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row24_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row25_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row25_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row25_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row26_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row26_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row26_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row29_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row29_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row29_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row31_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row31_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row31_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row32_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row32_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row32_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row33_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row33_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row33_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row35_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row35_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row35_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row36_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row36_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row37_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row37_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row37_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row39_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row39_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row39_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row41_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row41_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row41_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row43_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row43_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row43_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row44_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row44_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row44_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row45_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row45_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row45_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row47_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row47_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row47_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row48_col3,#T_24cdff9a_9964_11ec_902e_0242c0a83004row48_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row48_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row48_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row50_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row50_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row50_col6,#T_24cdff9a_9964_11ec_902e_0242c0a83004row51_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row51_col5,#T_ ...
#             width:  10em;
#              height:  80%;
#         }#T_24cdff9a_9964_11ec_902e_0242c0a83004row2_col2,#T_24cdff9a_9964_11ec_902e_0242c0a83004row2_col3,#T_24cdff9a_9964_11ec_902e_0242c0a83004row2_col4,#T_24cdff9a_9964_11ec_902e_0242c0a83004row2_col5,#T_24cdff9a_9964_11ec_902e_0242c0a83004row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 66.5%, transparent 66.5%);
#         }#T_24cdff9a_9964_11ec_902e_0242c0a83004row3_col2,#T_24cdff9a_9964_11ec_902e_0242c0a83004row3_col3{
#             width:  10em;
#              height:  80%

# %% [markdown]
# ## Detailanalyse Brondata naar Staging

# %%
df = df_brondata.merge(df_staging, on=['Table', 'Aantal_Records', 'Aantal_tabellen'], how='outer', suffixes=("_brondata", "_staging"))
df[df.Stage_brondata.isnull() | df.Stage_staging.isnull() ]
# Out:
#                      Table                                 Projecten_brondata  \
# 7              AARDEWERK 2  [DC20, DC27, DC36, DC72, DC37, DC29, DC05, DC2...
# 31                PBAKOPIE                                              [CMA]
# 39                     PBA                                              [CMA]
# 40                  SKELET                                             [DC39]
# 41                 pesthof                                          [pesthof]
# 44             voorstraat1                                       [VOORSTRAAT]
# 48  AARDEWERK 1&2 VOORWERP                                             [DB34]
# 59               ARTF_PIJP                         [DC24_STADSKANTOOR, DC154]
# 68             AARDEWERK 2                                                NaN
# 69                PBAKOPIE                                                NaN
# 70                     PBA                                                NaN
# 71             voorstraat1                                                NaN
# 72                  SKELET                                                NaN
# 73                 pesthof                                                NaN
# 74                    FOTO                                                NaN
# 75               ARTF_PIJP                                                NaN
#
#     Aantal_Records  Aantal_tabellen Stage_brondata  \
# 7              904                9       Brondata
# 31             256                1       Brondata
# 39             186                1       Brondata
# 40             179                1       Brondata
# 41             178                1       Brondata
# 44             155                1       Brondata
# 48              96                1       Brondata
# 59              28                2       Brondata
# 68             903                9            NaN
# 69             255                1            NaN
# 70             185                1            NaN
# 71             154                1            NaN
# 72             151                1            NaN
# 73             148                1            NaN
# 74              88                2            NaN
# 75              27                2            NaN
#
#                                     Projecten_staging Stage_staging
# 7                                                 NaN           NaN
# 31                                                NaN           NaN
# 39                                                NaN           NaN
# 40                                                NaN           NaN
# 41                                                NaN           NaN
# 44                                                NaN           NaN
# 48                                                NaN           NaN
# 59                                                NaN           NaN
# 68  [DC37, DC36, DC20, DC05, DC27, DC29, DC21, DC3...       Staging
# 69                                              [CMA]       Staging
# 70                                              [CMA]       Staging
# 71                                       [VOORSTRAAT]       Staging
# 72                                             [DC39]       Staging
# 73                                          [pesthof]       Staging
# 74                                     [DC154, DC179]       Staging
# 75                         [DC154, DC24_STADSKANTOOR]       Staging

# %% [markdown]
# ## Detailanalyse Staging naar SingleStore

# %%
df = df_staging.merge(df_singlestore, on=['Table', 'Aantal_Records', 'Aantal_tabellen'], how='outer', suffixes=("_staging", "_singlestore"))
df[df.Stage_singlestore.isnull() | df.Stage_staging.isnull() ]
# Out:
#                                    Table  \
# 1                     Aardewerk 1 backup
# 3                           DIAOPGRAVING
# 4                      Controle vondsten
# 6                              VULLINGEN
# 14                            TEKENINGEN
# 15                               VULLING
# 16       Kopie van Kopie van AARDEWERK 1
# 21                               PUT_VAK
# 24                           DIAVOORWERP
# 25                            VONDSTINHD
# 26                            backupHOUT
# 29                   GIS_SPOOR_STRUCTOBJ
# 31                              PBAKOPIE
# 32                 Kopie van AARDEWERK 1
# 33                          SPOOR_INHOUD
# 35                            VAK_VONDST
# 37                             Fotolijst
# 39                                   PBA
# 41              Tellijst_Vondstmateriaal
# 42                           voorstraat1
# 44                               pesthof
# 45  LIJST VONDSTEN  URGENTE CONSERVERING
# 47                         REF_SPOORAARD
# 49                             voorstr22
# 50                                  FOTO
# 51                      foto opname form
# 54                                  MUUR
# 56                     Palen_lakenramen2
# 57               GIS_STRUCTOBJ_STRUCTOBJ
# 59                    Buikmonsters KV-IV
# 61                           vondstlijst
# 62                              TEKENING
# 66                               PROJECT
# 68                         magazijnlijst
# 69                                doosnr
# 70                           OPGRAVINGEN
# 71                          VINDPLAATSEN
# 72                            stellingen
#
#                                     Projecten_staging  Aantal_Records  \
# 1                                              [DB34]            4465
# 3   [HHD2, DC29, DC03, DC97, DC30, DC21, DB34, DC0...            2057
# 4                                              [DB34]            1466
# 6         [DC30, DC112, DC93, DC29, DB34, HHD2, DC97]            1060
# 14  [DC33, DB34, DC31, DC03, DC11, DC32, DC05, DC2...             614
# 15                                     [DC179, DC154]             526
# 16                                             [HHD2]             515
# 21                                            [DC179]             335
# 24  [DC27, DC20, DC03, DC32, DC23, DC29, DC18, DC2...             310
# 25                  [DC24_STADSKANTOOR, DC154, DC179]             300
# 26  [DC29, HHD2, DC34, DC30, DC23, DC21, DB34, DC3...             277
# 29                                     [DC179, DC008]             270
# 31                                              [CMA]             255
# 32                                       [HHD2, DC97]             246
# 33                                            [DC179]             208
# 35                                            [DC179]             204
# 37                                            [DC112]             199
# 39                                              [CMA]             185
# 41                                            [DC179]             158
# 42                                       [VOORSTRAAT]             154
# 44                                          [pesthof]             148
# 45                                             [DB34]             129
# 47                                            [DC112]              96
# 49                                               [aw]              89
# 50                                     [DC154, DC179]              88
# 51                                              [dia]              87
# 54                                     [DC179, DC008]              72
# 56                                            [DC179]              39
# 57                                            [DC179]              38
# 59                                             [DB34]              27
# 61                         [VOORSTRAAT VONDSTENLIJST]              20
# 62                                [DC24_STADSKANTOOR]              15
# 66                                     [DC008, DC179]               7
# 68                                                NaN           11268
# 69                                                NaN            5546
# 70                                                NaN             840
# 71                                                NaN              37
# 72                                                NaN              22
#
#     Aantal_tabellen Stage_staging Projecten_singlestore Stage_singlestore
# 1                 1       Staging                   NaN               NaN
# 3                13       Staging                   NaN               NaN
# 4                 1       Staging                   NaN               NaN
# 6                 7       Staging                   NaN               NaN
# 14               29       Staging                   NaN               NaN
# 15                2       Staging                   NaN               NaN
# 16                1       Staging                   NaN               NaN
# 21                1       Staging                   NaN               NaN
# 24               12       Staging                   NaN               NaN
# 25                3       Staging                   NaN               NaN
# 26               17       Staging                   NaN               NaN
# 29                2       Staging                   NaN               NaN
# 31                1       Staging                   NaN               NaN
# 32                2       Staging                   NaN               NaN
# 33                1       Staging                   NaN               NaN
# 35                1       Staging                   NaN               NaN
# 37                1       Staging                   NaN               NaN
# 39                1       Staging                   NaN               NaN
# 41                1       Staging                   NaN               NaN
# 42                1       Staging                   NaN               NaN
# 44                1       Staging                   NaN               NaN
# 45                1       Staging                   NaN               NaN
# 47                1       Staging                   NaN               NaN
# 49                1       Staging                   NaN               NaN
# 50                2       Staging                   NaN               NaN
# 51                1       Staging                   NaN               NaN
# 54                2       Staging                   NaN               NaN
# 56                1       Staging                   NaN               NaN
# 57                1       Staging                   NaN               NaN
# 59                1       Staging                   NaN               NaN
# 61                1       Staging                   NaN               NaN
# 62                1       Staging                   NaN               NaN
# 66                2       Staging                   NaN               NaN
# 68                1           NaN            [MAGAZIJN]       SingleStore
# 69                1           NaN            [MAGAZIJN]       SingleStore
# 70                1           NaN             [DELF-IT]       SingleStore
# 71                1           NaN             [DELF-IT]       SingleStore
# 72                1           NaN            [MAGAZIJN]       SingleStore

# %% [markdown]
# ## Detailanalyse SingleStore naar Doelsysteem

# %%
df = df_singlestore.merge(df_doelsysteem, on=['Table', 'Aantal_Records', 'Aantal_tabellen'], how='outer', suffixes=("_singlestore", "_doelsysteem"))
df[df.Stage_singlestore.isnull() | df.Stage_doelsysteem.isnull() ]
# Out:
#                Table              Projecten_singlestore  Aantal_Records  \
# 0      magazijnlijst                         [MAGAZIJN]           11268
# 1             doosnr                         [MAGAZIJN]            5546
# 23          ARTEFACT  [DC24_STADSKANTOOR, DC154, DC179]             203
# 33              VLAK  [DC179, DC154, DC24_STADSKANTOOR]              34
# 36               PUT  [DC154, DC179, DC24_STADSKANTOOR]              13
# 40     magazijnlijst                                NaN            5634
# 41            doosnr                                NaN            2773
# 42  generated_vondst                                NaN            2112
# 43   generated_spoor                                NaN             472
# 44    generated_Doos                                NaN              57
#
#     Aantal_tabellen Stage_singlestore  \
# 0                 1       SingleStore
# 1                 1       SingleStore
# 23                3       SingleStore
# 33                3       SingleStore
# 36                3       SingleStore
# 40                1               NaN
# 41                1               NaN
# 42               27               NaN
# 43                7               NaN
# 44               14               NaN
#
#                                 Projecten_doelsysteem Stage_doelsysteem
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 23                                                NaN               NaN
# 33                                                NaN               NaN
# 36                                                NaN               NaN
# 40                                         [MAGAZIJN]       Doelsysteem
# 41                                         [MAGAZIJN]       Doelsysteem
# 42  [DB008, DB034, DC004, DC005, DC008, DC009, DC0...       Doelsysteem
# 43  [DB034, DC033, DC039, DC093, DC097, DC112, HHD...       Doelsysteem
# 44  [DB034, DC005, DC011, DC018, DC021, DC024, DC0...       Doelsysteem

# %%
# Experiments to be able to parse the mongo bson strings to either JSON or dict
# Not wirking :(((


startQ_regex = re.compile(r"({|\(|,\s*|:\s*)\'") # regex to replace first quote of words to double quaote
endQ_regex = re.compile(r"\'(:|\)|,|})") # regex to replace last quote of words to double quaote
regex = re.compile(r'ObjectId\((.*)\)') # regex to replace Object

# Does not work :(
def getFromJson(brondata):    
    if not brondata or brondata != "":
        brondata = brondata.replace('\"', '\'')
        brondata = startQ_regex.sub('\\1"', brondata)
        brondata = endQ_regex.sub('"\\1', brondata)
        brondata = regex.sub('\\1', brondata)
        brondata = brondata.replace('),', ',') # Quick fix because one ) could not be removed
        print(brondata)
        obj = json.loads(brondata)
        
        return obj
    else: 
        return {} 


#import re
#from bson.json_util import dumps, loads

#p = re.compile(r'blue (?P<animal>dog|cat)')
#p.sub(r'gray \g<animal>',s)
#re.sub(
#    pattern=r'ObjectId\((.*)\)', 
#    repl='\\1', 
#    string=str
#)

str = "{'_id': ObjectId('61e5f4a0ef919b0974d0395d'), 'LOKATIE': 'H:\\GEMEENTES\\PLAATS\\Opgravingen\\NAAM\\opgravingCODE.mdb', 'CODE': 'PN023', 'TOPONIEM': "Karitaat 'Molensloot", 'OPGRAVING': 'Vispaaiplaats Ruijven', 'CODENAAM': 'PN023', 'KAARTBLAD': '37E', 'XCOORD': 87523, 'YCOORD': 445002, 'JAAR': 2013, 'VONDSTENLIJST': 0, 'SPOREN': 0, 'DIAOPGRAVING': 0, 'DIAVOORWERP': 0, 'TEKENINGEN': 0, 'ROMEINS AARDEWERK': 0, 'AARDEWERK 1': 0, 'AARDEWERK 2': 0, 'KLEIPIJPEN': 0, 'TERRA COTTA': 0, 'GLAS': 0, 'BEEN': 0, 'BOT': 0, 'HOORN': 0, 'IVOOR': 0, 'HOUT': 0, 'METAAL': 0, 'MUNTEN EN PENNINGEN': 0, 'STEEN': 0, 'LEER': 0, 'TEXTIEL': 0, 'MODERN': 0, 'BIOLOGISCH': 0, 'SPECIAL': 0, 'IJZ': 0, 'ROM': 0, 'MIDDELEEUWS OF LATER': 0, 'VME': 0, 'LME': 0, 'LMEA': 0, 'LMEB': 0, 'NT': 0, 'WAARNEMING': 57944, 'table': 'OPGRAVINGEN', 'project': 'DELF-IT', 'bron': 'opgravingDELF-IT', 'loadtime': '2022-01-17T22:58:31+00:00'}"
#str = str.replace("\\", "/")
#str = str.replace("\'", "###")
#str = str.replace("\"", "\'")
#str = str.replace("###", "\"")


#str = re.sub(
#    pattern=r'ObjectId\((.*)\)', 
#    repl='\\1', 
#    string=str)

#json.loads(str)
#str = re.sub(
#    pattern=r"\'(.*?)\'(:|}|,)", 
#    repl='"\\1"\\2', 
#    string=str
#)
from ast import literal_eval
#d = eval(str)
#d['_id']

import yaml
yaml.load(str)
# Out:
#   Input In [14]
#     str = "{'_id': ObjectId('61e5f4a0ef919b0974d0395d'), 'LOKATIE': 'H:\\GEMEENTES\\PLAATS\\Opgravingen\\NAAM\\opgravingCODE.mdb', 'CODE': 'PN023', 'TOPONIEM': "Karitaat 'Molensloot", 'OPGRAVING': 'Vispaaiplaats Ruijven', 'CODENAAM': 'PN023', 'KAARTBLAD': '37E', 'XCOORD': 87523, 'YCOORD': 445002, 'JAAR': 2013, 'VONDSTENLIJST': 0, 'SPOREN': 0, 'DIAOPGRAVING': 0, 'DIAVOORWERP': 0, 'TEKENINGEN': 0, 'ROMEINS AARDEWERK': 0, 'AARDEWERK 1': 0, 'AARDEWERK 2': 0, 'KLEIPIJPEN': 0, 'TERRA COTTA': 0, 'GLAS': 0, 'BEEN': 0, 'BOT': 0, 'HOORN': 0, 'IVOOR': 0, 'HOUT': 0, 'METAAL': 0, 'MUNTEN EN PENNINGEN': 0, 'STEEN': 0, 'LEER': 0, 'TEXTIEL': 0, 'MODERN': 0, 'BIOLOGISCH': 0, 'SPECIAL': 0, 'IJZ': 0, 'ROM': 0, 'MIDDELEEUWS OF LATER': 0, 'VME': 0, 'LME': 0, 'LMEA': 0, 'LMEB': 0, 'NT': 0, 'WAARNEMING': 57944, 'table': 'OPGRAVINGEN', 'project': 'DELF-IT', 'bron': 'opgravingDELF-IT', 'loadtime': '2022-01-17T22:58:31+00:00'}"
#                                                                                                                                                                  ^
# SyntaxError: invalid syntax

# %%
grp_aggr = [{"$match" : {'project': {'$nin': ['MAGAZIJN', 'DELF-IT', 'Digifotos']}, 'table': { '$not': {'$regex':"^SYS.*"}}}}]

df_text = pd.DataFrame(list(metaCollection.aggregate(grp_aggr)))
text = ' '.join(list(df_text['name']))
text

# %%
# Import package
import matplotlib.pyplot as plt
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off")

# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width= 3000, height = 2000, collocations=False, stopwords = STOPWORDS).generate(text)
# Plot
plot_cloud(wordcloud)
